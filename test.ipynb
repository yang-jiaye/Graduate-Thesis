# %%
import pycocotools.mask
import numpy as np
before = np.random.rand(100, 100, 1) > 0.5
foo = pycocotools.mask.encode(np.asarray(before, order="F"))

print(foo)

after = pycocotools.mask.decode(foo)
# Out:
# [{'size': [100, 100], 'counts': b'...;...:...;...>1BO0O131MN151KN021N10N03000O2ONO23011LM0011OO01010N0031N3OL2011NOO2002N00N021N01OO80H00113OL0240L20L1010N0102050I210ONO12OO1O12NN32NOOO011O0000O020N020N4010K10O:1HOO000O00010O001001OO0200000N30O1N0021M25NK0'}]

# %%
rle = foo[0]['counts']
rle = str(rle)
# Out:
# "b'...;...:...;...>1BO0O131MN151KN021N10N03000O2ONO23011LM0011OO01010N0031N3OL2011NOO2002N00N021N01OO80H00113OL0240L20L1010N0102050I210ONO12OO1O12NN32NOOO011O0000O020N020N4010K10O:1HOO000O00010O001001OO0200000N30O1N0021M25NK0'"

# %%
from matplotlib import pyplot as plt
plt.imshow(before)
plt.show()

# %%
import pycocotools.mask
from matplotlib import pyplot as plt
rle = {'size': [375, 1242], 'counts':  "YSZ8k0h:"}
after = pycocotools.mask.decode(rle)
plt.imshow(after)
plt.show()

# %%
s = ("ss", "ss")
print(type(s))
# Out:
# <class 'tuple'>
